# %%
#used packages
import torch
import json
################################1. preparing the utilities functions to process our data
#Here we define the utilities function to process our data, i.e. nodes and edges and thier features (attributes)
#For representing this data in the PyG data format, we first define a method load_node_csv() that reads 
#in a *.csv file and returns a node-level feature representation x of shape [num_nodes, num_features]:

###############################1.1 function to Load node-realted data
#load_node_csv() reads the *.csv file from path, and creates a dictionary mapping that maps its index column 
#to a consecutive value e.g., the representation of a resource in the first row should be accessible via x[0].

def load_node_csv(path, mapping, encoders=None, **kwargs):
    x_mapping = {}
    df = pd.read_csv(path, index_col="resourceid", **kwargs)
    
    # Update x_mapping with unique node IDs, excluding "None"
    for index in df.index.unique():
        if index != "None":
            x_mapping[index] = len(x_mapping)
    
    # Update mapping dictionary with unique node IDs, excluding "None"
    unique_ids = df.index.unique()
    for node_id in unique_ids:
        if node_id != "None" and node_id not in mapping:
            mapping[node_id] = len(mapping)
    
    # Create indices tensor
    indices = torch.tensor([mapping[node_id] for node_id in unique_ids if node_id != "None"])
    #print("indices", indices)
    
    x = None
    if encoders is not None:
        xs = [encoder(df.loc[df.index != "None", col]) for col, encoder in encoders.items()]
        x = torch.stack(xs, dim=1)
        # Uncomment the following line if you want to concatenate indices with encoded features
        # x = torch.cat((indices.unsqueeze(1), torch.stack(xs, dim=1)), dim=1)

    return x, x_mapping

################################################2.2 function to Load edge-related data
#loading of edges 
#load_edge_csv() returns the final edge_index representation of shape [2, number_of_each_edges_types] 
#from *.csv

def load_edge_csv(path, src_mapping, dst_mapping, encoders=None, **kwargs):
    # Read the CSV file
    df = pd.read_csv(path, **kwargs)
    # Assuming the first column is the source index column and the second is the destination index column
    src_index_col = df.columns[0]
    dst_index_col = df.columns[1]
    src = []
    dst = []
    valid_rows = []

    # Map source and destination indices using provided mappings, skipping "None"
    for i, (src_index, dst_index) in enumerate(zip(df[src_index_col], df[dst_index_col])):
        if src_index != "None" and dst_index != "None":
            src.append(src_mapping[src_index])
            dst.append(dst_mapping[dst_index])
            valid_rows.append(i)
    
    # Create edge_index tensor
    edge_index = torch.tensor([src, dst], dtype=torch.long)
    edge_attr = None
    if encoders is not None:
        # Apply encoders only to valid rows
        edge_attrs = [encoder(df.loc[valid_rows, col]) for col, encoder in encoders.items()]
        edge_attr = torch.cat(edge_attrs, dim=-1)

    return edge_index, edge_attr

#src_index_col and dst_index_col define the index columns of source and destination nodes, 
#encoders are used to return additional edge-level feature information using one of NLP models


################################################1.3 function to define an encoder that applies on of NLP model to encode node/edgae related features 
from sentence_transformers import SentenceTransformer
class SequenceEncoder(object):
    def __init__(self, model_name='all-MiniLM-L6-v2', device=None):
        self.device = device
        self.model = SentenceTransformer(model_name, device=device)

    @torch.no_grad()
    def __call__(self, df):
        x = self.model.encode(df.values, show_progress_bar=True,
                              convert_to_tensor=True, device=self.device)
        return x.cpu()


class ProviderEncoder(object):
    def __call__(self, df):
        tensor_val=torch.tensor(df.values,dtype=torch.float)

        return tensor_val.cpu()
class TypeEncoder(object):
    def __call__(self, df):
        tensor_val=torch.tensor(df.values,dtype=torch.float)

        return tensor_val.cpu()

class LocationEncoder(object):
    def __init__(self, dtype=None):
        self.dtype = dtype

    def __call__(self, df):
        tensor_val=torch.tensor(df.values,dtype=torch.float)

        return tensor_val.cpu()

def load_labels(path):
##load the labels of services
      with open(path) as f:
        labels = json.load(f)
        print (labels)
      return labels 
########################2) Load the data from the given dataset using the defined utilities functions

#steps:
#A) load graphs from CSV files 
from torch_geometric.data import download_url, extract_zip
import pandas as pd
from torch_geometric.data import HeteroData
from torch_geometric.loader import DataLoader
import os
def load_data(dir_path,labels,service_label,mapping):

  providers = os.listdir(dir_path)
  data_set = []
  graph_i=0
  for provider in providers:
          services=os.listdir(dir_path+'/'+provider)
          for service in services:
                     #graph_mapping.update({provider+'-'+service+'-'+instance: graph_i})
                     service_files=os.listdir(dir_path+'/'+provider+'/'+service)
                     path=dir_path+'/'+provider+'/'+service+'/'
                    # print(service_files)
                     resource_path = path+'nodes.csv'
                     #1) load nodes
                     resource_x,mapping_x = load_node_csv(
                     resource_path, mapping, encoders={
                      'type': TypeEncoder(), 
                      'provider':ProviderEncoder()
                       
                       })
                     #print(resource_path)
                      #initialize our HeteroData object and pass the node type into it
                     data= HeteroData()
                     data['resource'].x = resource_x
                                #2 load edges
                     for file in service_files:
                            if ('.csv' in file) and (file!='nodes.csv'):
                                    edge_path=path+file
                                    edge_index_relationship, edge_label_relationship= load_edge_csv(
                                    edge_path,
                                    src_mapping=mapping_x,
                                    dst_mapping=mapping_x,
                                    encoders=None,)  
                                    relation_name=file.replace('.csv', '')
                                    if edge_index_relationship.size(1)!=0:
                                        data['resource', relation_name, 'resource'].edge_index =  edge_index_relationship
                     data.y=torch.tensor(int(labels[provider+'_'+service_label]), dtype=torch.long) 
                     data_set.append(data)

                     graph_i+=1


  print(mapping)
  return data_set

# %%
#Generate training data
import random
import os
##Put here the path of dataset
current_folder = 'C:/env/'
mapping={}
label_path = os.path.join(current_folder, 'Heterogeneous_Graph_Learning/dataset/service_labels.json')
labels=load_labels(label_path)
#dir_path=r'Heterogeneous_Graph_Learning/dataset/services/'
dir_path=os.path.join(current_folder,'Heterogeneous_Graph_Learning/dataset/services/')

#will generate dataset for each service so that we can organize the finale dataset into training and testing in a fair way
L2B_graphs_path =dir_path+'L2bridging'
L2C_graphs_path =dir_path+'L2Connectivity'
L2E_graphs_path =dir_path+'L2endpoint'
L3R_graphs_path =dir_path+'L3routing'
NIC_graphs_path =dir_path+'NIC'
#Peering_graphs_path =dir_path+'peering_services' (Removed for now)

L2B_services=load_data(L2B_graphs_path,labels,'L2bridging',mapping)#
L2C_services=load_data(L2C_graphs_path,labels,'L2Connectivity',mapping)#
L2E_services=load_data(L2E_graphs_path,labels,'L2endpoint',mapping)#
L3R_services=load_data(L3R_graphs_path,labels,'L3routing',mapping)#
NIC_services=load_data(NIC_graphs_path,labels,'NIC',mapping)#
#Peering_services=load_data(Peering_graphs_path,labels)# (Removed for now)
# Out:
# {'aws_NIC': '0', 'azure_NIC': '1', 'aws_L2Connectivity': '2', 'azure_L2Connectivity': '3', 'aws_L2endpoint': '4', 'azure_L2endpoint': '5', 'aws_L2bridging': '6', 'azure_L2bridging': '7', 'aws_L3routing': '8', 'azure_L3routing': '9', 'aws_peering': '10', 'azure_peering': '11'}
# {'L2_Bridging': 0, 'Node_L2Domain': 1, 'Node_L3Domain': 2, 'Subnet': 3}
# {'L2_Bridging': 0, 'Node_L2Domain': 1, 'Node_L3Domain': 2, 'Subnet': 3, 'L2Address': 4, 'L2_Endpoint': 5, 'VM': 6}
# {'L2_Bridging': 0, 'Node_L2Domain': 1, 'Node_L3Domain': 2, 'Subnet': 3, 'L2Address': 4, 'L2_Endpoint': 5, 'VM': 6}
# {'L2_Bridging': 0, 'Node_L2Domain': 1, 'Node_L3Domain': 2, 'Subnet': 3, 'L2Address': 4, 'L2_Endpoint': 5, 'VM': 6, 'L3Address3': 7, 'L3EndPointServiceDestination': 8, 'L3EndPointServiceSource': 9, 'L3RouterService': 10, 'Subnet1_To_Subnet2': 11, 'Subnet2_To_Subnet1': 12, 'Subnet3': 13}
# {'L2_Bridging': 0, 'Node_L2Domain': 1, 'Node_L3Domain': 2, 'Subnet': 3, 'L2Address': 4, 'L2_Endpoint': 5, 'VM': 6, 'L3Address3': 7, 'L3EndPointServiceDestination': 8, 'L3EndPointServiceSource': 9, 'L3RouterService': 10, 'Subnet1_To_Subnet2': 11, 'Subnet2_To_Subnet1': 12, 'Subnet3': 13, 'L3Address': 14, 'L3_Endpoint': 15}

# %%
#shuffling datac
random.shuffle(L2B_services)
random.shuffle(L2C_services)
random.shuffle(L2E_services)
random.shuffle(L3R_services)
random.shuffle(NIC_services)
#random.shuffle(Peering_services)(Removed for now)
print(len(L2B_services))
print(len(L2C_services))
print(len(L2E_services))
print(len(L3R_services))
print(len(NIC_services))
#print(len(Peering_services))(Removed for now)

#training
training_data_set=L2B_services[:250]+L2C_services[:250]+L2E_services[:250]+L3R_services[:60]+NIC_services[:250]
#+Peering_services[:300]
print(len(training_data_set))
random.shuffle(training_data_set)
#testing 

testing_data_set=L2B_services[250:]+L2C_services[250:]+L2E_services[250:]+L3R_services[60:]+NIC_services[250:]
#Peering_services[300:]
print(len(testing_data_set))
random.shuffle(testing_data_set)
#Printing some training and testing data
print (training_data_set[0])
print(testing_data_set[2])
# Out:
# 320
# 320
# 320
# 81
# 320
# 1060
# 301
# HeteroData(
#   y=0,
#   resource={ x=[9, 2] },
#   (resource, Belong_To, resource)={ edge_index=[2, 1] },
#   (resource, exposes_resource_L2Address, resource)={ edge_index=[2, 1] },
#   (resource, exposes_resource_L3Address, resource)={ edge_index=[2, 1] },
#   (resource, exposes_resource_Subnet, resource)={ edge_index=[2, 1] },
#   (resource, Hosted_On_L2Domain, resource)={ edge_index=[2, 1] },
#   (resource, Hosted_On_Node, resource)={ edge_index=[2, 2] },
#   (resource, Is_Owned_By, resource)={ edge_index=[2, 1] },
#   (resource, requires_service, resource)={ edge_index=[2, 2] },
#   (resource, Require_Resource_Subnet, resource)={ edge_index=[2, 1] }
# )
# HeteroData(
#   y=6,
#   resource={ x=[4, 2] },
#   (resource, exposes_resource_Subnet, resource)={ edge_index=[2, 1] },
#   (resource, Hosted_On_L2Domain, resource)={ edge_index=[2, 1] },
#   (resource, Is_Owned_By, resource)={ edge_index=[2, 1] }
# )

# %% [markdown]
# In this step, we want to train a model that takes the nodes features and predicts the type of edge among an edge type list.

# %%
def data_reformulation(loader):
    index = {}
    mapping = []
    labels = []

    for graph in loader:
        for typ in graph.edge_types:
            if typ not in index:
                index[typ] = len(index)
            edge_index = graph[typ]['edge_index']
            src, dst = edge_index[0], edge_index[1]
            for s, d in zip(src, dst):
                # Flatten the features of the source and destination nodes into a single list
                source_features = graph['resource'].x[s].tolist()
                destination_features = graph['resource'].x[d].tolist()
                combined_features = source_features + destination_features
                mapping.append(combined_features)
                labels.append(index[typ])
            
    return mapping, labels, index

# %%
datas=[]
datas.extend(training_data_set)
datas.extend(testing_data_set)
size=int(0.7*len(datas))
train=datas[:size]
test=datas[size:]

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
def train_model(training_data_set):
    mapping_training, labels_training, index_training = data_reformulation(training_data_set)
    classifier = RandomForestClassifier(n_estimators=100)
    classifier.fit(mapping_training, labels_training)
    return classifier, index_training

def evaluate_model(classifier, testing_data_set):
    mapping_testing, labels_testing, _ = data_reformulation(testing_data_set)
    y_pred = classifier.predict(mapping_testing)
    accuracy = accuracy_score(labels_testing, y_pred)
    return accuracy
for epoch in range(1, 5):
    classifier, index_training=train_model(train)
    val_acc_train = evaluate_model(classifier,train)
    print(f'Val train: {val_acc_train}')
    val_acc = evaluate_model(classifier,test)
    print(f'Val: {val_acc}')
# Out:
# Val train: 1.0
# Val: 0.2674285714285714
# Val train: 1.0
# Val: 0.2674285714285714
# Val train: 1.0
# Val: 0.2674285714285714
# Val train: 1.0
# Val: 0.2674285714285714

# %%
def predict_new_edges(classifier, mapping_new, index_training):
    y_pred = classifier.predict(mapping_new)
    
    # Convert predictions back to edge types using the index
    reverse_index = {v: k for k, v in index_training.items()}
    predicted_edge_types = [reverse_index[pred] for pred in y_pred]
    return predicted_edge_types

# %% [markdown]
# In this step, we are going to calculate the expression of the graphon.

# %%
import torch
from torch_geometric.data import HeteroData
import numpy as np

def create_adjacency_matrix(hetero_data):
    num_nodes = hetero_data['resource']['x'].shape[0]
    adj_matrix = np.zeros((num_nodes, num_nodes), dtype=int)
    for edge_type in hetero_data.edge_types:
        edge_index = hetero_data[edge_type]['edge_index']
        src, dst = edge_index[0], edge_index[1]
        for s, d in zip(src.tolist(), dst.tolist()):
            adj_matrix[s, d] = 1
    return adj_matrix
#return the adjancy matrix

# %%
import numpy as np
# computes the distribuation mu_m

def compute_mu_m(A_m):
    # Create the indicator vector 1_Nm
    iden_Nm = np.ones((A_m.shape[0],1))
    # Compute A_m * 1_Nm
    A_m_1_Nm = A_m @ iden_Nm
    # Compute the norm ||A_m * 1_Nm||_1
    norm_A_m_1_Nm = np.linalg.norm(A_m_1_Nm, 1)
    # Compute the final result
    mu_m = (1 / norm_A_m_1_Nm) * A_m_1_Nm

    return mu_m

# %%
from scipy.interpolate import interp1d
import numpy as np

#Computes the distribution mu_W
def compute_mu_W(mu_list, K):
    M = len(mu_list)
    interpolated_values = []
    
    for mu_m in mu_list:
        # Flatten and sort mu_m in descending order
        sorted_mu_m = np.sort(np.ravel(mu_m))[::-1]
        
        # Create the interpolation function
        x = np.linspace(0, len(sorted_mu_m) - 1, num=len(sorted_mu_m))
        interpolation_function = interp1d(x, sorted_mu_m, kind='linear', fill_value="extrapolate")
        
        # Interpolate K values
        xp = np.linspace(0, len(sorted_mu_m) - 1, num=K)
        interpolated_mu_m = interpolation_function(xp)
        
        # Collect interpolated values
        interpolated_values.append(interpolated_mu_m)
    
    # Average of interpolated values
    mu_W = np.mean(interpolated_values, axis=0)
    return mu_W.reshape(-1, 1)

# %%
def determine_N_max(loader):
    N_max=0
    for graph in loader:
        if len(graph['resource'].x)>N_max:
            N_max=len(graph['resource'].x)
    return N_max

# %%
import math
#Hyperparaters:
beta = 500  # Example value for beta
L = 5  # Number of outer iterations
S = 5  # Number of inner Sinkhorn iterations
epsilon = 1e-8

# %%
def initialize_W_uniform(shape):
    return np.random.uniform(0, 1, shape)

# %%
import numpy as np
import networkx as nx
from scipy.optimize import linprog
from scipy.interpolate import interp1d

def learning_graphons_via_gwb(A_M, beta, L, S, N_max):
    # Step 1: Initialization
    K=math.floor(N_max / np.log(N_max)) 
    M = len(A_M)
    W = initialize_W_uniform((K, K))
    MU_m=[compute_mu_m(A_m) for A_m in A_M ]
    mu_w=compute_mu_W(MU_m,K)
    for l in range(L):
        T_list = []
        for m in range(M):
            a=MU_m[m]
            T_m = MU_m[m] @mu_w.T
            T = T_m.copy()
            Am = A_M[m]
            Dm =(Am*Am)@MU_m[m]@np.ones((1,K))+np.ones((len(Am),1))@mu_w.T@(W*W)
            # Initialize Dm here, needs to be defined based on your data
            for s in range(S):
                C = np.exp(-1 / beta * (Dm - 2 * Am @ T@(W.T)) * T)
                b = mu_w / ((C.T) @ a+epsilon)
                a = MU_m[m] / (C @ b+epsilon)
                diag_a=np.diag(np.ravel(a))
               
                diag_b=np.diag(np.ravel(b))
                T =diag_a  @ C @ diag_b
            T_list.append(T)
        W = sum(T_m.T @ Am @ T_m for T_m, Am in zip(T_list, A_M)) / M

    
    return W

# %%
import numpy as np

def create_intervals(K):
    interval_length = 1 / K
    intervals = [(i * interval_length, (i + 1) * interval_length) for i in range(K)]
    return intervals

def indicator(x, y, interval_x, interval_y):

    if interval_x[0] <= x < interval_x[1] and interval_y[0] <= y < interval_y[1]:
        return 1
    return 0

def W2_p(x, y, K, weights):
   
    intervals = create_intervals(K)
    W2_p_value = 0
    for k in range(K):
        for k_prime in range(K):
            interval_k = intervals[k]
            interval_k_prime = intervals[k_prime]
            indicator_value = indicator(x, y, interval_k, interval_k_prime)
            W2_p_value += weights[k, k_prime] * indicator_value
    return W2_p_value

# %%
#returns the classes within a loader
def classes(loader):
    y_values = [data.y.item() for data in loader]
    return(y_values)

# %%
def labels_dataset(loader):
    new_data_set=[]
    for graph in loader:
        new_data_set.append((graph.y,graph)) 
    return(new_data_set)

# %%
def sort_matrix_by_degree(adj_matrix, features_matrix):
    degrees = np.sum(adj_matrix, axis=1)
    # Get sorted indices based on degree
    sorted_indices = np.argsort(degrees)
    
    # Sort adjacency matrix and features matrix based on sorted indices
    sorted_adj_matrix = adj_matrix[sorted_indices, :][:, sorted_indices]
    sorted_features_matrix = features_matrix[sorted_indices, :]
    
    return sorted_adj_matrix, sorted_features_matrix

# %%
import numpy as np

def average_pooling(features_matrix, N_max):
    K=math.floor(N_max / np.log(N_max)) 
    num_nodes, num_features = features_matrix.shape

    if K > num_nodes:
        raise ValueError("K cannot be greater than the number of nodes.")

    # Determine segment size
    segment_size = num_nodes // K

    # Add remaining nodes to the last segment if num_nodes is not perfectly divisible by K
    segment_size = max(segment_size, 1)

    # Add remaining nodes to the last segment if necessary
    segments = [features_matrix[i:i+segment_size] for i in range(0, num_nodes, segment_size)]
    
    if len(segments) < K:
        # If there are fewer segments than K, merge the last few segments
        segments[-2] = np.vstack((segments[-2], *segments[-1]))
        segments = segments[:-1]
    
    # Apply average pooling to each segment
    pooled_matrix = np.array([np.mean(segment, axis=0) for segment in segments])
    
    # If there are more segments than K, we need to truncate the number of segments
    if len(pooled_matrix) > K:
        pooled_matrix = pooled_matrix[:K]

    return pooled_matrix

# %%
def estimator(label,loader):
    labled_data = []
    new_data_set=labels_dataset(loader)
    for y in new_data_set:
        if y[0] == label:
            labled_data.append(y[1])
    
    global_sorted_adjancy = []
    global_sorted_features = []
    
    for graph in labled_data:
        features = np.stack([t.numpy() for t in graph['resource'].x])
        sorted_adjancy_matrix, sorted_feature_matrix = sort_matrix_by_degree(create_adjacency_matrix(graph), features)
        global_sorted_adjancy.append(sorted_adjancy_matrix)
        global_sorted_features.append(sorted_feature_matrix)
    N_max = determine_N_max(loader)
    weights = learning_graphons_via_gwb(global_sorted_adjancy, beta, L, S, N_max)
    all_pooled_features = np.vstack(features)
    # Compute the mean of the pooled features
    X_G = average_pooling(all_pooled_features, N_max)    
    return weights, X_G

# %%
import numpy as np
import torch
from torch_geometric.data import HeteroData
import random


import numpy as np
import torch
from torch_geometric.data import HeteroData

def generate_synthetic_graph(W, X_graphon, classe, liste_of_edges):
    # Step 1: Sample K nodes independently from Unif[0,1]
    K = len(W)
    u = np.random.uniform(0, 1, K)

    # Initialize HeteroData
    graph = HeteroData()

    # Step 2: Generate the adjacency matrix A
    A = np.zeros((K, K), dtype=int)
    src = []
    dst = []
    nodes=[]
    for i in range(K):
        for j in range(K):
            if i != j:
                prob = W2_p(u[i], u[j], K, W)
                A[i, j] = np.random.binomial(1, prob)
                if A[i, j] == 1:
                    src.append(i)
                    dst.append(j)
    if (len(src) == 0) and (len(dst)==0):
        return 0
    node = {}
    current_index = 0

    for s in range(K):
        if (s in src) or (s in dst):
            if s not in node:
                node[s] = current_index
                current_index += 1
                nodes.append(X_graphon[s,:])


    X=np.array(nodes)
    for s in range(len(src)) :
        source=src[s]
        src[s]=node[source]
    for d in range(len(dst)):
        target=dst[d]
        dst[d]=node[target]
        
    combined_features = []

    for s, d in zip(src, dst):
        combined_list = list(X[s, :]) + list(X[d, :])
        combined_features.append(combined_list)
        combined_feature = np.array(combined_features)
        predicted_edge_types = predict_new_edges(classifier, combined_feature, index_training)

     
    X = torch.tensor(X, dtype=torch.float)
    graph['resource'].x = X
    n=len(nodes)
    # Create edge types tensor
    for lab in predicted_edge_types:
        occurrence = [i for i, x in enumerate(predicted_edge_types) if x == lab]
        if occurrence:
            index = [[src[i] for i in occurrence], [dst[i] for i in occurrence]]
            graph[ lab].edge_index = torch.tensor(index, dtype=torch.long)
    
    graph.y = torch.tensor(classe,dtype=torch.long)  # Assign the label to the graph

    return graph

# %%
liste_of_edges=  ['Belong_To', 'exposes_resource_L2Address',  'exposes_resource_L3Address', 'exposes_resource_L3SimpleRoute', 'exposes_resource_Subnet', 'Hosted_On_L2Domain', 'Hosted_On_L3Domain', 'Hosted_On_Node', 'Is_Owned_By', 'requires_service','Require_Resource_Subnet']

# %%
import random
def class_densities(loader):
    # Assuming labels_dataset and classes are predefined functions
    labels=classes(loader) 
    uniq_classes = len(set(labels))
    density = np.zeros(uniq_classes)
 
    for label in (labels):
        density[label] += 1
    density /= len(labels)  # Normalize by the total number of samples
    return density

def gmixup(loader,alpha_aug,alpha):
    I=[]
    labbels=classes(loader)
    density=class_densities(loader)
    for i in range(len(density)):
        density[i]=1/density[i] 
        density[i]+=+ 10**(-5)
        
    density/= (np.sum(density))
    print(density)

    # Sample synthetic graphs
    num_synthetic = int(alpha_aug * len(loader))
    for _ in range(num_synthetic):
        lambda_mix = np.random.beta(alpha, alpha)
        label1=np.random.choice(len(density), p=density)
        label2=np.random.choice(len(density), p=density)
        if lambda_mix<0.5:
            label=label2
            label2=label1
            label1=label            
        W_G,X_G=estimator(label1,loader)
        W_H,X_H=estimator(label2,loader)
        W_I = lambda_mix * W_G + (1 - lambda_mix) * W_H
        X_I = lambda_mix * X_G + (1 - lambda_mix) * X_H
        label_I=int(lambda_mix * label1 + (1 - lambda_mix) * label2)
        synthetic_graph = generate_synthetic_graph(W_I, X_I,label_I,liste_of_edges)
        if synthetic_graph != 0: 
            I.append(synthetic_graph)

    return I

# %%
augmented_training_data=gmixup(training_data_set,10,0.5)
augmented_testing_data=gmixup(testing_data_set,10,0.5)
# Out:
# [0.05701185 0.0579314  0.05281981 0.06301309 0.06139738 0.05401123
#  0.05936771 0.055686   0.35917432 0.1795872 ]
# [0.06108143 0.06848523 0.08370415 0.05255845 0.04913073 0.09416716
#  0.05380984 0.08071472 0.28250132 0.173847  ]

# %%
graphs=augmented_training_data+augmented_testing_data

# %%
for data in graphs:
    print(data['resource'].x)
    print (data.edge_index_dict)
# Out:
# tensor([[5.9998, 0.9999],
#         [7.5003, 0.9999]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0000, 0.0417],
#         [4.0000, 0.0417]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0, 1],
#         [1, 0]])}
# tensor([[9.4107, 1.0000],
#         [6.1768, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.9053, 0.9684],
#         [7.4526, 0.9684]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.5016, 0.1672],
#         [7.5016, 0.1672]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0000, 1.0000],
#         [7.6564, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.3147, 0.0787],
#         [6.3147, 0.0787]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.0867, 0.9827],
#         [6.0173, 0.9827],
#         [7.0173, 0.9827]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [2]])}
# tensor([[8.8082, 0.5233],
#         [1.9068, 0.5233]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.2109, 0.1156],
#         [8.8640, 0.1156]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6., 0.],
#         [8., 0.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0000, 0.8164],
#         [7.5000, 0.8164]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8711, 0.0644],
#         [4.3544, 0.0644]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.0000, 0.3568],
#         [7.0000, 0.3568]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.3114, 0.8962],
#         [6.3634, 0.8962],
#         [7.3114, 0.8962]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [2]])}
# tensor([[0.1244, 0.9689],
#         [1.2644, 0.9689]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.4939, 0.3976],
#         [8.1085, 0.3976]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.9722, 0.2778],
#         [7.8333, 0.2778]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.6272, 0.1045],
#         [6.2091, 0.1045]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.7313, 0.0000],
#         [3.9224, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.1502, 0.0601],
#         [7.6502, 0.0601]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0514, 0.6270],
#         [8.4325, 0.6270]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.7268, 0.0000],
#         [7.7273, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9532, 1.0000],
#         [4.1286, 1.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9989e+00, 4.3815e-04],
#         [6.0015e+00, 4.3815e-04]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.8456, 1.0000],
#         [8.3456, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0559, 0.1574],
#         [3.5279, 0.1574],
#         [7.2640, 0.1574]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1, 1],
#         [0, 2]])}
# tensor([[5.7399, 1.0000],
#         [7.8251, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.1674, 0.0000],
#         [7.1674, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.0545, 0.4055],
#         [6.5945, 0.4055]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[8.7168, 1.0000],
#         [8.5399, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.0000],
#         [7.5000, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.0029, 0.0000],
#         [9.6023, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0229, 0.9908],
#         [5.9817, 0.9908]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.2471, 0.8765],
#         [9.6911, 0.8765]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.9933, 0.6027],
#         [8.7946, 0.6027]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.1677, 0.0000],
#         [8.6677, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.0000e+00, 1.0747e-03],
#         [7.0000e+00, 1.0747e-03]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.1974, 0.0000],
#         [3.8816, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0553, 0.9862],
#         [6.0553, 0.9862]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8248, 0.0000],
#         [7.7190, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.3098, 0.0000],
#         [7.8282, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.5798, 0.3160],
#         [7.3160, 0.3160]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.0370, 0.4074],
#         [3.9630, 0.4074]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8884, 0.0000],
#         [7.0279, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.2053, 0.2821],
#         [8.5126, 0.2821]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.9031, 0.4796],
#         [4.9592, 0.4796]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0000e+00, 9.7736e-05],
#         [7.5000e+00, 9.7736e-05]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.2003, 0.4401],
#         [3.7997, 0.4401],
#         [4.8801, 0.4401]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [2]])}
# tensor([[9.0298, 0.0000],
#         [7.3583, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9862, 0.0069],
#         [4.0381, 0.0069]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0., 0.],
#         [8., 0.]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  0.0706],
#         [ 0.9294,  0.0706],
#         [ 6.9294,  0.0706]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [2]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[2],
#         [0]])}
# tensor([[0.2398, 0.9680],
#         [5.9360, 0.9680],
#         [8.0640, 0.9680]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [2]])}
# tensor([[5.9949, 0.0000],
#         [7.0064, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8098, 0.9049],
#         [8.1902, 0.9049]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.9897, 0.0000],
#         [7.9897, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.7014, 0.0000],
#         [5.5463, 0.0000],
#         [7.5671, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [0]])}
# tensor([[4.0048, 0.0000],
#         [6.6010, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.5304, 1.0000],
#         [8.0304, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.4380, 0.2603],
#         [7.1095, 0.2603]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.0142, 0.9974],
#         [7.5064, 0.9974]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.4619, 0.0000],
#         [7.3845, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  0.7434],
#         [ 1.0000,  0.7434]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.7541, 0.1229],
#         [7.3073, 0.1229],
#         [8.2459, 0.1229]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.3957],
#         [7.0000, 0.3957]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.6128, 1.0000],
#         [7.6021, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.5972, 0.0000],
#         [7.7714, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.1188, 0.1865],
#         [1.5594, 0.1865]])
# {('resource', 'requires_service', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.0870, 0.2282],
#         [7.5600, 0.2282]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.7492, 0.8746],
#         [7.3136, 0.8746]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.0992, 1.0000],
#         [8.0794, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.5627, 1.0000],
#         [8.0627, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.6412, 1.0000],
#         [5.4565, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.9985, 1.0000],
#         [7.5001, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.2066, 0.1609],
#         [5.6783, 0.1609],
#         [7.4022, 0.1609]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1, 2],
#         [2, 0]])}
# tensor([[9.3346, 0.7338],
#         [7.0646, 0.7338]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.1262, 0.0000],
#         [8.1009, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0593, 0.9763],
#         [4.1305, 0.9763]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0218, 0.6022],
#         [6.7956, 0.6022]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8849, 1.0000],
#         [4.3165, 1.0000],
#         [7.6439, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0, 2],
#         [1, 0]])}
# tensor([[6.0000, 0.0231],
#         [7.5000, 0.0231]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.8898, 0.9559],
#         [0.1763, 0.9559]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.0622, 0.9793],
#         [7.0622, 0.9793]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.2199, 1.0000],
#         [6.8680, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.8773, 1.0000],
#         [7.1473, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.3561, 0.0000],
#         [8.1624, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.3327, 0.7776],
#         [7.8888, 0.7776]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0027, 0.9995],
#         [3.9984, 0.9995]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.2582, 0.6989],
#         [7.7527, 0.6989]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.8179, 1.0000],
#         [0.2914, 1.0000],
#         [6.2914, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [2]]), ('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.1342, 0.0000],
#         [7.1151, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.0831, 0.0000],
#         [7.1834, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.9841, 1.0000],
#         [6.0222, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.8640, 0.8848],
#         [5.7696, 0.8848]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  1.0000],
#         [ 7.0000,  1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.2792, 0.5279],
#         [6.4721, 0.5279]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.7849, 0.6860],
#         [5.3721, 0.6860]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.2606, 0.0000],
#         [6.7734, 0.0000],
#         [8.7606, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.5311, 0.6625],
#         [5.3250, 0.6625]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.4368, 1.0000],
#         [6.9011, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.7979, 0.0000],
#         [7.9326, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.7270, 0.8635],
#         [7.3412, 0.8635]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9774, 0.6090],
#         [8.4774, 0.6090]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0000, 0.7739],
#         [6.0000, 0.7739]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  1.0000],
#         [ 0.9197,  1.0000]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.5889, 0.3528],
#         [8.5889, 0.3528]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.8811, 0.6476],
#         [8.7049, 0.6476]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6., 1.],
#         [7., 1.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.9022, 0.0000],
#         [7.9101, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.8387, 0.9355],
#         [6.2259, 0.9355]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.7828, 0.3783],
#         [6.6217, 0.3783]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.3554, 1.0000],
#         [1.7553, 1.0000]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.0654, 0.0000],
#         [7.0654, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.7787, 0.9262],
#         [7.3894, 0.9262]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.4420, 0.9558],
#         [7.9116, 0.9558]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.7626, 0.0000],
#         [7.7626, 0.0000]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.2393, 0.0239],
#         [6.8564, 0.0239]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.2480, 0.0000],
#         [6.6496, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.7118, 0.0000],
#         [4.2882, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.2897, 0.0000],
#         [8.8773, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9998e+00, 1.1173e-04],
#         [7.5003e+00, 1.1173e-04]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.9260, 0.0765],
#         [9.3087, 0.0765]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[8.3811, 0.0000],
#         [5.3524, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.0871, 0.0000],
#         [5.4350, 0.0000]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.6913, 0.0000],
#         [5.5210, 0.0000],
#         [8.1913, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0, 2],
#         [1, 0]])}
# tensor([[9.1003, 0.8401],
#         [9.6802, 0.8401]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.9143, 0.4343],
#         [7.7371, 0.4343]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8038, 0.8392],
#         [3.5177, 0.8392]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9188, 0.0135],
#         [7.4797, 0.0135]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.6116, 0.0000],
#         [4.5554, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.0285, 0.9967],
#         [6.0134, 0.9967]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.9138, 0.9655],
#         [1.1034, 0.9655]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.6233, 0.4561],
#         [8.1757, 0.4561]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.3140, 0.0000],
#         [5.8865, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.4180, 1.0000],
#         [6.4180, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0000, 0.0182],
#         [6.0000, 0.0182]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.0669, 0.0335],
#         [7.4833, 0.0335]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.4563, 0.0000],
#         [6.7087, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.1677, 0.0000],
#         [6.1677, 0.0000]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6., 1.],
#         [8., 1.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.2712e-03, 3.2712e-04],
#         [6.9997e+00, 3.2712e-04]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.7087, 1.0000],
#         [8.6141, 1.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  0.5493],
#         [ 0.0000,  0.5493]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0., 0.],
#         [8., 0.]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.7288, 0.0000],
#         [7.6247, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.6002, 0.3001],
#         [9.2498, 0.3001]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.7666, 0.0467],
#         [6.9533, 0.0467]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9953e+00, 2.3586e-03],
#         [8.0047e+00, 2.3586e-03]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.3462, 0.0000],
#         [7.2968, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.9886, 0.2825],
#         [7.8474, 0.2825]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 1.0000],
#         [7.7539, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.3345, 0.0000],
#         [7.3345, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.7909, 0.0000],
#         [7.6318, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.1900, 0.9655],
#         [7.5863, 0.9655]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.9603, 0.4618],
#         [8.8456, 0.4618]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.2694, 0.0000],
#         [8.6476, 0.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0371, 1.0000],
#         [5.1703, 1.0000],
#         [8.5371, 1.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [0]])}
# tensor([[5.7570, 0.5857],
#         [7.7928, 0.5857]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.4926, 0.2537],
#         [8.1343, 0.2537]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.5211, 0.8803],
#         [8.4824, 0.8803]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.8657, 0.0000],
#         [1.4567, 0.0000]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9162, 0.0000],
#         [8.0838, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.9068, 0.7814],
#         [6.0000, 0.7814]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9381, 0.0000],
#         [1.0742, 0.0000]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.3223, 1.0000],
#         [1.0843, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.0626, 0.9886],
#         [7.5284, 0.9886]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.9912, 0.4985],
#         [6.7478, 0.4985]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.5920, 0.6408],
#         [6.6408, 0.6408]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9522, 0.0096],
#         [6.9904, 0.0096]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.0888, 0.0000],
#         [7.0888, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.5567, 0.7773],
#         [8.4453, 0.7773]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.0000],
#         [4.4153, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9991, 0.9996],
#         [6.0013, 0.9996]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.1030, 0.0000],
#         [6.4267, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.7090, 0.7164],
#         [5.4328, 0.7164]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.4395e-03, 0.0000e+00],
#         [5.9988e+00, 0.0000e+00]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.,  1.],
#         [ 6.,  1.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.1855, 0.9753],
#         [8.0495, 0.9753]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.3205, 0.4718],
#         [6.9050, 0.4718],
#         [8.8205, 0.4718]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0, 2],
#         [1, 1]])}
# tensor([[7.4997, 0.0000],
#         [4.9999, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.5489, 0.0000],
#         [5.5609, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.3053, 0.0000],
#         [7.3053, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.7455, 0.0424],
#         [6.7455, 0.0424]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.9180, 0.9672],
#         [1.0984, 0.9672],
#         [6.1147, 0.9672],
#         [7.0984, 0.9672]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [3]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [1]])}
# tensor([[5.0288, 1.0000],
#         [7.5288, 1.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.2336, 0.7066],
#         [8.8263, 0.7066]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.6906, 1.0000],
#         [4.8509, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0., 1.],
#         [1., 1.]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.9774, 1.0000],
#         [7.5023, 1.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.8226, 0.9291],
#         [7.2128, 0.9291]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.4294, 0.7853],
#         [9.4632, 0.7853]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.7455, 0.7673],
#         [5.5345, 0.7673]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.4271, 0.8854],
#         [6.8854, 0.8854]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.5830, 1.0000],
#         [7.1166, 1.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0000, 0.0000],
#         [6.0000, 0.0000]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.4910, 0.9018],
#         [5.4108, 0.9018],
#         [7.3527, 0.9018]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [1]])}
# tensor([[5.0220, 0.9912],
#         [5.9824, 0.9912]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.2340, 0.0000],
#         [9.7872, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.8005, 0.6999],
#         [6.6002, 0.6999]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.6577, 0.4877],
#         [8.2192, 0.4877],
#         [8.9754, 0.4877]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [2]])}
# tensor([[10.0000,  0.6479],
#         [ 6.0000,  0.6479]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.8702, 0.0000],
#         [6.1817, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.,  1.],
#         [ 1.,  1.]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0000, 0.1634],
#         [4.0000, 0.1634]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.8914, 0.0000],
#         [1.1304, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6., 0.],
#         [7., 0.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.2647, 0.0000],
#         [7.2529, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.5830, 0.0000],
#         [3.4170, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.2285, 0.0000],
#         [5.8172, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.5716, 0.0000],
#         [7.1572, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9503, 0.9901],
#         [1.0497, 0.9901],
#         [7.0050, 0.9901]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [2]])}
# tensor([[8.9704, 0.1030],
#         [7.1030, 0.1030]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8091, 0.6763],
#         [5.3527, 0.6763]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  0.6822],
#         [ 0.6822,  0.6822],
#         [ 4.4108,  0.6822],
#         [ 6.6822,  0.6822]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [3]]), ('resource', 'requires_service', 'resource'): tensor([[2],
#         [1]])}
# tensor([[5.6045, 0.7582],
#         [5.5164, 0.7582]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.1326, 0.9735],
#         [6.0265, 0.9735]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.4587, 1.0000],
#         [6.7293, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.4359, 0.0000],
#         [8.5641, 0.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.3441, 0.1312],
#         [7.5656, 0.1312]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.5143, 0.8486],
#         [6.0914, 0.8486]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.9988, 0.0999],
#         [6.9001, 0.0999]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.3648, 0.8541],
#         [7.8648, 0.8541]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.4493, 0.7584],
#         [2.4493, 0.7584]])
# {('resource', 'requires_service', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.3326, 0.0665],
#         [7.0333, 0.0665]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8105, 0.0948],
#         [7.0474, 0.0948]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.8359, 0.0000],
#         [4.0821, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.9110, 0.0000],
#         [5.7571, 0.0000],
#         [8.2429, 0.0000]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [2]])}
# tensor([[4.2657, 0.4266],
#         [3.8671, 0.4266],
#         [7.5734, 0.4266]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0, 1],
#         [2, 2]])}
# tensor([[6.7368, 0.2632],
#         [7.7368, 0.2632]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.2027, 0.7063],
#         [5.4126, 0.7063]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.0000, 0.0000],
#         [8.0000, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.1739, 0.7652],
#         [4.4696, 0.7652]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0000, 1.0000],
#         [6.0000, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.9857, 1.0000],
#         [8.9857, 1.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.4203, 0.0000],
#         [5.6638, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9863, 1.0000],
#         [0.0165, 1.0000],
#         [6.0041, 1.0000]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]]), ('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[1],
#         [2]])}
# tensor([[4.0690, 0.0000],
#         [6.5931, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.0000],
#         [6.0559, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9859, 0.0000],
#         [4.0388, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.9362, 0.2582],
#         [8.5163, 0.2582]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.8517, 1.0000],
#         [7.3148, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.4452, 0.0000],
#         [5.5256, 0.0000],
#         [8.1935, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1, 2],
#         [0, 1]])}
# tensor([[1.8791, 0.1034],
#         [6.4137, 0.1034]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9058, 0.0377],
#         [7.1130, 0.0377]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.8354, 1.0000],
#         [8.1646, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.2144, 0.0000],
#         [7.0536, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.1031, 0.0000],
#         [8.0825, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.2532, 0.8338],
#         [9.0844, 0.8338],
#         [9.6675, 0.8338]])
# {('resource', 'Belong_To', 'resource'): tensor([[1, 2],
#         [0, 1]])}
# tensor([[8.9062, 0.0000],
#         [4.7190, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.3035, 0.0000],
#         [7.3035, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.1553, 0.9689],
#         [3.9068, 0.9689]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9798, 0.0000],
#         [0.0324, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.1083, 1.0000],
#         [8.0289, 1.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9780, 0.9890],
#         [7.5275, 0.9890]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0000, 0.0000],
#         [7.5000, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.0000],
#         [7.6414, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.2173, 0.8783],
#         [6.2696, 0.8783],
#         [7.7565, 0.8783]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.4032, 0.9328],
#         [1.4032, 0.9328]])
# {('resource', 'requires_service', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  0.0000],
#         [ 5.9423,  0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.0991, 0.9604],
#         [8.0792, 0.9604]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.2179, 0.2957],
#         [7.7393, 0.2957]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.9894, 0.9958],
#         [0.0169, 0.9958]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.7716, 0.9086],
#         [1.7766, 0.9086]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0445, 0.9889],
#         [1.0946, 0.9889]])
# {('resource', 'requires_service', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.0000, 0.5181],
#         [8.0000, 0.5181]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0317, 1.0000],
#         [6.2697, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0000, 0.6401],
#         [6.0000, 0.6401],
#         [7.5000, 0.6401]])
# {('resource', 'Belong_To', 'resource'): tensor([[1, 2],
#         [0, 1]])}
# tensor([[9.7514, 0.0000],
#         [1.8452, 0.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.8780, 0.4244],
#         [6.6366, 0.4244]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0000, 0.8892],
#         [7.9446, 0.8892]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0748, 0.0000],
#         [6.5443, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.1738, 1.0000],
#         [7.7652, 1.0000]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.1872, 1.0000],
#         [7.0813, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.2646, 0.4339],
#         [8.2646, 0.4339]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0000, 0.8832],
#         [6.6495, 0.8832]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.7467, 0.0000],
#         [7.2489, 0.0000],
#         [8.1991, 0.0000]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[2],
#         [1]])}
# tensor([[1.8204e-02, 3.6408e-03],
#         [6.0000e+00, 3.6408e-03],
#         [6.9891e+00, 3.6408e-03]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[2],
#         [0]])}
# tensor([[7., 0.],
#         [8., 0.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.0608, 0.0000],
#         [8.0487, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.6380, 0.9362],
#         [7.9362, 0.9362]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.1808, 1.0000],
#         [6.5979, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.6536, 0.6643],
#         [9.1607, 0.6643]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.1268, 0.3746],
#         [7.6873, 0.3746]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.0731, 0.0000],
#         [5.6292, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.7595, 0.0000],
#         [6.0000, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.7755, 0.7633],
#         [5.5265, 0.7633]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.7950, 0.3795],
#         [4.7230, 0.3795],
#         [7.2410, 0.3795]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [0]])}
# tensor([[4.2138, 0.0000],
#         [7.5972, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[3.5264, 0.3526],
#         [3.8841, 0.3526]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.6136, 0.8068],
#         [8.3864, 0.8068]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9333, 0.9667],
#         [7.5833, 0.9667]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.0879, 0.0293],
#         [7.0879, 0.0293]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.3657, 1.0000],
#         [9.0299, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.1676, 1.0000],
#         [7.6676, 1.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.0056, 0.3315],
#         [8.3399, 0.3315]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9903, 0.0000],
#         [7.5122, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9972e+00, 1.1282e-03],
#         [1.0034e+00, 1.1282e-03],
#         [7.0034e+00, 1.1282e-03]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [2]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[2],
#         [0]])}
# tensor([[0.6854, 0.9086],
#         [5.8172, 0.9086],
#         [7.2285, 0.9086]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [0]])}
# tensor([[9.8909, 0.0000],
#         [7.1309, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.5292, 0.9377],
#         [6.2490, 0.9377]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.5456e-02, 2.5456e-03],
#         [7.9949e+00, 2.5456e-03]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.8312, 0.0281],
#         [7.9437, 0.0281]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[3.0524, 0.5895],
#         [7.2052, 0.5895]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0729, 0.9903],
#         [5.9806, 0.9903],
#         [7.0243, 0.9903]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [1]])}
# tensor([[9.9930e+00, 1.3970e-03],
#         [1.0070e+00, 1.3970e-03]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.6184, 0.5527],
#         [8.6580, 0.5527]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0000, 0.9339],
#         [6.0000, 0.9339]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.0039, 0.0000],
#         [1.5938, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.7396, 0.3698],
#         [8.5755, 0.3698]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.0000, 1.0000],
#         [7.5000, 1.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.8257, 0.0000],
#         [5.5131, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.0000],
#         [7.9998, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1., 0.],
#         [6., 0.]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.2638, 0.0000],
#         [9.6702, 0.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.4251, 0.4300],
#         [8.9251, 0.4300]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  0.9451],
#         [ 6.9451,  0.9451]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.2675, 0.4268],
#         [6.5732, 0.4268]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.1108, 0.0000],
#         [6.9335, 0.0000]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.2651, 1.0000],
#         [7.1470, 1.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0000, 0.3924],
#         [7.6962, 0.3924]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.8404, 0.9362],
#         [1.1915, 0.9362]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.4558, 0.1823],
#         [5.0028, 0.1823]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0, 1],
#         [1, 0]])}
# tensor([[9.3065, 1.0000],
#         [9.9120, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5., 1.],
#         [4., 1.]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0833, 0.9667],
#         [4.1833, 0.9667]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0007, 0.0000],
#         [5.9995, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.7966, 0.0203],
#         [0.1220, 0.0203]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0684, 0.0000],
#         [3.9589, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.3532, 1.0000],
#         [5.7174, 1.0000],
#         [7.8532, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1, 2],
#         [0, 1]])}
# tensor([[8.5656, 1.0000],
#         [7.1434, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6., 0.],
#         [7., 0.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.3709, 0.4629],
#         [7.4629, 0.4629]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.2992, 0.0000],
#         [5.9202, 0.0000],
#         [7.0997, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [1]])}
# tensor([[9.9519e+00, 9.6118e-03],
#         [6.0144e+00, 9.6118e-03]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0914, 0.9739],
#         [7.0783, 0.9739]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9978, 0.0000],
#         [7.0026, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0000, 0.1652],
#         [4.0000, 0.1652]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.,  1.],
#         [ 6.,  1.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0000, 0.9954],
#         [6.0000, 0.9954]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0193, 0.0000],
#         [6.2424, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.5842, 0.7120],
#         [8.2201, 0.7120]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.9884, 0.7349],
#         [7.6628, 0.7349]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9576, 0.9915],
#         [5.9830, 0.9915]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0007, 0.9997],
#         [4.0016, 0.9997]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.0020, 1.0000],
#         [7.0020, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.1023, 0.9829],
#         [6.0256, 0.9829]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.0000e+00, 1.2149e-03],
#         [8.0000e+00, 1.2149e-03]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.3451, 0.0000],
#         [8.0920, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.0018, 0.0000],
#         [7.5018, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.4568, 0.0000],
#         [7.9568, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.2468, 0.0000],
#         [5.4009, 0.0000],
#         [7.7489, 0.0000],
#         [8.5991, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[2, 3],
#         [1, 0]])}
# tensor([[4.9506, 0.0000],
#         [7.2624, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.3178, 0.0000],
#         [7.8527, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.4201, 0.8600],
# ...
# tensor([[4.8454, 0.5773],
#         [7.1753, 0.5773]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9943e+00, 1.0000e+00],
#         [9.0566e-03, 1.0000e+00]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.2361, 1.0000],
#         [9.1296, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.3610, 1.0000],
#         [1.0225, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9634, 0.0183],
#         [7.5457, 0.0183]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  0.2752],
#         [ 1.0000,  0.2752],
#         [ 7.0000,  0.2752]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[2],
#         [1]])}
# tensor([[5.4507, 1.0000],
#         [5.5493, 1.0000],
#         [4.1803, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [2]]), ('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[2, 2],
#         [0, 1]])}
# tensor([[5.9633, 1.0000],
#         [7.9927, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  1.0000],
#         [ 1.3447,  1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.0000, 0.5064],
#         [6.0000, 0.5064]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5., 0.],
#         [6., 0.]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.5088, 1.0000],
#         [1.5895, 1.0000],
#         [6.6877, 1.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[1],
#         [0]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [1]])}
# tensor([[5.9362, 0.0319],
#         [7.0798, 0.0319]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0884, 0.0088],
#         [6.9912, 0.0088]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.0019, 0.0000],
#         [6.0009, 0.0000]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1., 1.],
#         [6., 1.]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.0265, 1.0000],
#         [9.5941, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[8.3994, 0.3201],
#         [1.9604, 0.3201]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.2454, 0.6182],
#         [7.5272, 0.6182]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.0000, 0.9275],
#         [1.0000, 0.9275]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.5008, 1.0000],
#         [6.6988, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.1469, 1.0000],
#         [6.6294, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.7413, 0.2471],
#         [6.8648, 0.2471]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000, 0.1137],
#         [4.3410, 0.1137]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.1672e-03, 9.9971e-01],
#         [5.9994e+00, 9.9971e-01],
#         [8.0006e+00, 9.9971e-01]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [2]])}
# tensor([[0.0000, 0.8891],
#         [8.0000, 0.8891]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.2450, 0.0000],
#         [4.5390, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.6893, 0.0000],
#         [9.3107, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.7335, 0.7689],
#         [7.5778, 0.7689]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.5163, 0.8065],
#         [6.6771, 0.8065]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.0891, 1.0000],
#         [7.9911, 1.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.7860, 0.2381],
#         [7.5953, 0.2381]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.3052, 0.0610],
#         [7.4084, 0.0610]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.6772, 0.7743],
#         [7.6772, 0.7743]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.7975, 1.0000],
#         [7.2658, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.2153, 1.0000],
#         [3.8708, 1.0000],
#         [7.4354, 1.0000]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [2]])}
# tensor([[0.0160, 0.0000],
#         [6.9984, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.7951, 0.9180],
#         [1.2459, 0.9180]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.7872, 0.1064],
#         [4.5853, 0.1064]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.1982, 0.5604],
#         [2.6811, 0.5604]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  0.7914],
#         [ 6.7914,  0.7914]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.0473, 0.0000],
#         [6.0237, 0.0000]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.6313, 0.1475],
#         [0.5899, 0.1475]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.4417, 0.0000],
#         [7.8139, 0.0000]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8083, 0.9042],
#         [7.7396, 0.9042]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.8418, 0.5367],
#         [1.8531, 0.5367],
#         [4.9378, 0.5367]])
# {('resource', 'requires_service', 'resource'): tensor([[1],
#         [2]]), ('resource', 'Hosted_On_Node', 'resource'): tensor([[2],
#         [0]])}
# tensor([[6.2358, 0.3764],
#         [7.3764, 0.3764]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9989, 0.0000],
#         [4.0004, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.4526, 0.7810],
#         [6.8758, 0.7810]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.8321, 1.0000],
#         [6.1664, 1.0000]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.8167, 0.4733],
#         [5.0231, 0.4733]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  1.0000],
#         [ 5.9024,  1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0., 0.],
#         [6., 0.]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.1125, 0.0000],
#         [5.9100, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1., 1.],
#         [6., 1.]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.0000, 0.8768],
#         [7.0000, 0.8768],
#         [8.0000, 0.8768]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [2]])}
# tensor([[9.8898, 0.0000],
#         [6.1763, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.5978, 1.0000],
#         [6.9196, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.7145, 0.8858],
#         [7.3426, 0.8858]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0506, 0.0000],
#         [5.9392, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.2147, 1.0000],
#         [8.1718, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0000, 0.6635],
#         [8.0000, 0.6635]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.2713, 0.3085],
#         [9.0744, 0.3085]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.,  1.],
#         [ 6.,  1.],
#         [ 7.,  1.]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1, 2],
#         [0, 0]])}
# tensor([[2.6482, 0.3380],
#         [6.6273, 0.3380]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.3634, 0.8789],
#         [7.3634, 0.8789]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.3135, 1.0000],
#         [7.7687, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.2952, 0.0000],
#         [7.2952, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.7366, 0.8683],
#         [4.7243, 0.8683]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1., 1.],
#         [6., 1.]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8557, 0.9279],
#         [4.3968, 0.9279]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9259, 0.9630],
#         [7.0926, 0.9630]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[8.4021, 0.3608],
#         [8.9175, 0.3608]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.8680, 0.0000],
#         [8.1320, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[4.9983, 1.0000],
#         [9.0017, 1.0000]])
# {('resource', 'Hosted_On_Node', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9655, 0.9942],
#         [7.9885, 0.9942]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.9578, 0.0000],
#         [5.9831, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.5381, 0.9462],
#         [5.7309, 0.9462]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.8985, 0.3797],
#         [6.0000, 0.3797],
#         [7.8102, 0.3797]])
# {('resource', 'Require_Resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[1, 1],
#         [0, 2]])}
# tensor([[0.0000e+00, 9.7266e-04],
#         [8.0000e+00, 9.7266e-04]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.4773, 0.0000],
#         [6.1193, 0.0000]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.6192, 1.0000],
#         [7.0381, 1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.0617, 0.0000],
#         [7.5281, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.1117, 0.0447],
#         [4.2457, 0.0447]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.0000, 0.9831],
#         [7.0000, 0.9831],
#         [8.0000, 0.9831]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.5140, 0.0000],
#         [5.3365, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[6.0000e+00, 5.2428e-07],
#         [4.0000e+00, 5.2428e-07]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[7.0228, 0.9909],
#         [8.0182, 0.9909]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.6514, 0.7394],
#         [5.4331, 0.7394]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.2929, 0.2155],
#         [6.4310, 0.2155]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[1.1682, 1.0000],
#         [7.0336, 1.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  0.9890],
#         [ 1.0000,  0.9890]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[10.0000,  1.0000],
#         [ 6.5188,  1.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[2.4318, 0.4864],
#         [5.5409, 0.4864]])
# {('resource', 'requires_service', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  0.9073],
#         [ 6.9073,  0.9073]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.0000, 0.0000],
#         [7.5000, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.9284, 0.0000],
#         [8.9002, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.0000, 0.9308],
#         [7.5000, 0.9308]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.9942, 1.0000],
#         [7.0072, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[4.4736, 0.4035],
#         [8.4912, 0.4035]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.0680, 0.5728],
#         [6.3496, 0.5728]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[6.7031, 0.0000],
#         [6.9891, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[0],
#         [1]])}
# tensor([[7.6279, 0.0511],
#         [9.8466, 0.0511]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  0.6807],
#         [ 0.6807,  0.6807]])
# {('resource', 'exposes_resource_L2Address', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.9579, 0.9789],
#         [8.0421, 0.9789]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[2.5265, 0.0000],
#         [5.3263, 0.0000],
#         [7.8422, 0.0000]])
# {('resource', 'exposes_resource_Subnet', 'resource'): tensor([[0],
#         [2]]), ('resource', 'Belong_To', 'resource'): tensor([[2],
#         [1]])}
# tensor([[8.2531, 0.3012],
#         [2.7950, 0.3012]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[0.3821, 0.9491],
#         [7.1274, 0.9491]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[9.1122, 0.0705],
#         [9.8237, 0.0705]])
# {('resource', 'Belong_To', 'resource'): tensor([[1],
#         [0]])}
# tensor([[5.5128, 0.7949],
#         [5.1283, 0.7949]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[0.0000, 0.2487],
#         [1.0000, 0.2487]])
# {('resource', 'Hosted_On_L2Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[9.6194, 0.0000],
#         [0.2283, 0.0000],
#         [6.0761, 0.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]]), ('resource', 'Is_Owned_By', 'resource'): tensor([[2],
#         [1]])}
# tensor([[4.3071, 0.0000],
#         [6.6614, 0.0000]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[0],
#         [1]])}
# tensor([[5.0725, 0.0290],
#         [4.1595, 0.0290]])
# {('resource', 'Hosted_On_L3Domain', 'resource'): tensor([[1],
#         [0]])}
# tensor([[1.2784, 0.0000],
#         [7.0557, 0.0000]])
# {('resource', 'Is_Owned_By', 'resource'): tensor([[1],
#         [0]])}
# tensor([[8.8031, 1.0000],
#         [9.4425, 1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}
# tensor([[10.0000,  1.0000],
#         [ 0.1463,  1.0000]])
# {('resource', 'Belong_To', 'resource'): tensor([[0],
#         [1]])}

# %%
from collections import Counter
import matplotlib.pyplot as plt
y_values = [data.y.item() for data in graphs] 
occurrence_count = Counter(y_values)
labels, counts = zip(*occurrence_count.items())
plt.figure(figsize=(10, 6))
plt.bar(labels, counts, color='skyblue', edgecolor='black')
plt.title("Class distribution")
plt.xlabel('Class')
plt.ylabel("Distribution")
plt.xticks(labels)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import torch
import os

# Define the file path
file_path = 'C:\\env\\Heterogeneous_Graph_Learning\\GNN-Model\\Augmented.pt'

# Check if the file exists
if os.path.exists(file_path):
    print('no')
    # Load existing data
    existing_data = torch.load(file_path)
    
    if isinstance(existing_data, list):
        print("list")
        existing_data.extend(graphs)
    else:
        # Assuming existing_data is not a list, convert to list and append
        existing_data = [existing_data, graphs]
        print('ok')
    # Save the updated data back to the file
    torch.save(existing_data, file_path)
else:
    # If the file does not exist, create a new file and save the data
    torch.save(graphs, file_path)
# Out:
# no
# list

# %%
file_path = 'C:\\env\\Heterogeneous_Graph_Learning\\GNN-Model\\Augmented.pt'

torch.save(graphs, file_path)
